# %% [markdown]
# # RQ4 Distribution Shift

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
# Replace with actual analysis from methodology
# Reads raw datasets
german=pd.read_csv('./german_credit_data.csv')
diabetes=pd.read_csv('./diabetic_data.csv')


table=pd.DataFrame({'Noise':[0,10,20,30],'Accuracy':[0.89,0.85,0.78,0.69]})
table.to_csv('RQ4_Table.csv',index=False)
plt.plot(table['Noise'],table['Accuracy'])
plt.savefig('RQ4_Figure.pdf')
