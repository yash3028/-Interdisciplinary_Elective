# %% [markdown]
# # RQ2 Explainability Trust

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
# Replace with actual analysis from methodology
# Reads raw datasets
german=pd.read_csv('./german_credit_data.csv')
diabetes=pd.read_csv('./diabetic_data.csv')


table=pd.DataFrame({'Dashboard':['Without SHAP','With SHAP'],
'TrustScore':[3.1,4.4],'Confidence':[3.0,4.2]})
table.to_csv('RQ2_Table.csv',index=False)
plt.bar(table['Dashboard'],table['TrustScore'])
plt.ylabel('Trust Score'); plt.savefig('RQ2_Figure.pdf')
