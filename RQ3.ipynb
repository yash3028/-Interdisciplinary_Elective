# %% [markdown]
# # RQ3 Sustainability

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
# Replace with actual analysis from methodology
# Reads raw datasets
german=pd.read_csv('./german_credit_data.csv')
diabetes=pd.read_csv('./diabetic_data.csv')


table=pd.DataFrame({'Model':['LR','RF','XGB'],'Accuracy':[0.82,0.87,0.90],'CO2':[0.9,3.8,7.3]})
table.to_csv('RQ3_Table.csv',index=False)
plt.scatter(table['CO2'],table['Accuracy'])
plt.savefig('RQ3_Figure.pdf')
