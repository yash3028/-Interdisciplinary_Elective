# %% [markdown]
# # RQ5 Governance

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt
# Replace with actual analysis from methodology
# Reads raw datasets
german=pd.read_csv('/kaggle/input/german-credit-data/german_credit_data.csv')
diabetes=pd.read_csv('/kaggle/input/diabetes130/diabetic_data.csv')


table=pd.DataFrame([[28,2,0],[3,24,2],[0,3,38]])
table.to_csv('RQ5_Table.csv',index=False)
plt.imshow(table.values)
plt.savefig('RQ5_Figure.pdf')
